# %% [markdown]
# <h1 class="talk-title">Python in the Browser Age</p>
#
# <h2 class="talk-subtitle">Data Visualization in the IPython Notebook</p>
#
# <center>
#
# <p class="gap05"></p>
# <h3> Jake VanderPlas </h3>
# <h3>[@jakevdp](http://twitter.com/jakevdp)</h3>
# <h3>University of Washington</h3>
#
#
# <p class="gap2"></p>
# </center>

# %%
# %run talktools
# Out:
# <style>
# /*
#    Simple CSS styling for using IPython Notebooks for talks.
#
#    Author: Fernando Perez <fernando.perez@berkeley.edu>
# */
#
# talk-title
# {
#   color: #111133;
#   font-size: 220%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# talk-subtitle
# {
#   color: #111155;
#   font-size: 150%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   text-align: center;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 180%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html
# {
#   color: #2C5494;
#   font-family: Ubuntu;
#   font-size: 170%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .rendered_html h1
# {
#   color: #1111AA;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .rendered_html h2
# {
#   color: #111133;
# ...

# %% [markdown]
# ## Talk Outline:
#
# - [IPython notebook: visualization in context](Notebook.ipynb)
#
# - [The modern world of Python visualization](PythonVis.ipynb)
#
# - [Interacting with the Kernel: IPython widgets](Interaction.ipynb)
