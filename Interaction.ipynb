# %% [markdown]
# # Interacting with the Kernel: IPython widgets

# %%
# %run talktools
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# <style>
# /*
#    Simple CSS styling for using IPython Notebooks for talks.
#
#    Author: Fernando Perez <fernando.perez@berkeley.edu>
# */
#
# talk-title
# {
#   color: #111133;
#   font-size: 220%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# talk-subtitle
# {
#   color: #111155;
#   font-size: 150%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   text-align: center;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 180%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html
# {
#   color: #2C5494;
#   font-family: Ubuntu;
#   font-size: 170%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .rendered_html h1
# {
#   color: #1111AA;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .rendered_html h2
# {
#   color: #111133;
# ...

# %% [markdown]
# Importance of trial and error in vis
# (scatter plot sizes and opacities?)
